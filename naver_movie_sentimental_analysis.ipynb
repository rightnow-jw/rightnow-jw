# %% [markdown]
# <a href="https://colab.research.google.com/github/rightnow-jw/rightnow-jw/blob/main/naver_movie_sentimental_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 불러오기
#
#
# *   데이터 출처:https://github.com/e9t/nsmc/

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/e9t/nsmc/refs/heads/master/ratings_train.txt',sep = '\t')
df.head()
# Out:
#          id                                           document  label
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1

# %% [markdown]
# # EDA

# %%
# shape
df .shape
# Out:
# (150000, 3)

# %%
#null
df.isnull().sum()
# Out:
# id          0
# document    5
# label       0
# dtype: int64

# %%
df[df.isnull()]
# Out:
#         id document  label
# 0      NaN      NaN    NaN
# 1      NaN      NaN    NaN
# 2      NaN      NaN    NaN
# 3      NaN      NaN    NaN
# 4      NaN      NaN    NaN
# ...     ..      ...    ...
# 149995 NaN      NaN    NaN
# 149996 NaN      NaN    NaN
# 149997 NaN      NaN    NaN
# 149998 NaN      NaN    NaN
# 149999 NaN      NaN    NaN
#
# [150000 rows x 3 columns]

# %%
df[df['document'].isnull()]
# Out:
#              id document  label
# 25857   2172111      NaN      1
# 55737   6369843      NaN      1
# 110014  1034280      NaN      0
# 126782  5942978      NaN      0
# 140721  1034283      NaN      0

# %%
df.dropna(inplace = True)

# %%
df. shape
# Out:
# (149995, 3)

# %%
#텍스트길이
import seaborn  as sns
df['len'] = df['document'].str.len()
sns.his
# Out:
#          id                                           document  label  len
# 0   9976970                                아 더빙.. 진짜 짜증나네요 목소리      0   19
# 1   3819312                  흠...포스터보고 초딩영화줄....오버연기조차 가볍지 않구나      1   33
# 2  10265843                                  너무재밓었다그래서보는것을추천한다      0   17
# 3   9045019                      교도소 이야기구먼 ..솔직히 재미는 없다..평점 조정      0   29
# 4   6483659  사이몬페그의 익살스런 연기가 돋보였던 영화!스파이더맨에서 늙어보이기만 했던 커스틴 ...      1   61

# %%
import seaborn  as sns
